# %%
file = open("kickoff.txt")

line = file.read().replace("\n", " ")

# %%
line
# Out:
# "{34369: {'link': 'https://northeastern.zoom.us/j/96879452707?pwd=SWx6KzNoQ0MrM1lNSHdDM01sc1Mzdz09',   'class_email': 'IA-class+RY157@northeastern.edu',   'class_password': 'qG5)9cS6/AsD',   'classroom': 'RY157',   'StartTime': '08:00:00',   'Day': 'W',   'CourseId': 'MGSC2301',   'assign_to': 1},  35099: {'link': 'https://northeastern.zoom.us/j/95250289821?pwd=cG15Tmx0ZUlucG1BNUNBV1U2bzA4UT09',   'class_email': 'IA-class+RY296@northeastern.edu',   'class_password': '%w$[4C(dHDag',   'classroom': 'RY296',   'StartTime': '08:00:00',   'Day': 'W',   'CourseId': 'CHEM2321',   'assign_to': 1},  32272: {'link': 'https://northeastern.zoom.us/j/97791356361',   'class_email': 'IA-class+RY273@northeastern.edu',   'class_password': 'NaN',   'classroom': 'RY273',   'StartTime': '08:00:00',   'Day': 'W',   'CourseId': 'BUSN1101',   'assign_to': 1},  31324: {'link': 'Not Found',   'class_email': 'IA-class+RY275@northeastern.edu',   'class_password': '5UbY6&kZc%/$',   'classroom': 'RY275',   'Star
# ...

# %%
line = line.replace('"', '')

# %%
import ast

# %%
dict_kick = ast.literal_eval(line)

# %%
dict_kick
# Out:
# {34369: {'link': 'https://northeastern.zoom.us/j/96879452707?pwd=SWx6KzNoQ0MrM1lNSHdDM01sc1Mzdz09',
#   'class_email': 'IA-class+RY157@northeastern.edu',
#   'class_password': 'qG5)9cS6/AsD',
#   'classroom': 'RY157',
#   'StartTime': '08:00:00',
#   'Day': 'W',
#   'CourseId': 'MGSC2301',
#   'assign_to': 1},
#  35099: {'link': 'https://northeastern.zoom.us/j/95250289821?pwd=cG15Tmx0ZUlucG1BNUNBV1U2bzA4UT09',
#   'class_email': 'IA-class+RY296@northeastern.edu',
#   'class_password': '%w$[4C(dHDag',
#   'classroom': 'RY296',
#   'StartTime': '08:00:00',
#   'Day': 'W',
#   'CourseId': 'CHEM2321',
#   'assign_to': 1},
#  32272: {'link': 'https://northeastern.zoom.us/j/97791356361',
#   'class_email': 'IA-class+RY273@northeastern.edu',
#   'class_password': 'NaN',
#   'classroom': 'RY273',
#   'StartTime': '08:00:00',
#   'Day': 'W',
#   'CourseId': 'BUSN1101',
#   'assign_to': 1},
#  31324: {'link': 'Not Found',
#   'class_email': 'IA-class+RY275@northeastern.edu',
# ...

# %%
kick_list=list(dict_kick.values())

# %%
kick_list
# Out:
# [{'link': 'https://northeastern.zoom.us/j/96879452707?pwd=SWx6KzNoQ0MrM1lNSHdDM01sc1Mzdz09',
#   'class_email': 'IA-class+RY157@northeastern.edu',
#   'class_password': 'qG5)9cS6/AsD',
#   'classroom': 'RY157',
#   'StartTime': '08:00:00',
#   'Day': 'W',
#   'CourseId': 'MGSC2301',
#   'assign_to': 1},
#  {'link': 'https://northeastern.zoom.us/j/95250289821?pwd=cG15Tmx0ZUlucG1BNUNBV1U2bzA4UT09',
#   'class_email': 'IA-class+RY296@northeastern.edu',
#   'class_password': '%w$[4C(dHDag',
#   'classroom': 'RY296',
#   'StartTime': '08:00:00',
#   'Day': 'W',
#   'CourseId': 'CHEM2321',
#   'assign_to': 1},
#  {'link': 'https://northeastern.zoom.us/j/97791356361',
#   'class_email': 'IA-class+RY273@northeastern.edu',
#   'class_password': 'NaN',
#   'classroom': 'RY273',
#   'StartTime': '08:00:00',
#   'Day': 'W',
#   'CourseId': 'BUSN1101',
#   'assign_to': 1},
#  {'link': 'Not Found',
#   'class_email': 'IA-class+RY275@northeastern.edu',
#   'class_password': '5UbY6&kZc%/$',
# ...

# %%
list(filter(lambda person: person['classroom'] == 'RY296', kick_list))
# Out:
# [{'link': 'https://northeastern.zoom.us/j/95250289821?pwd=cG15Tmx0ZUlucG1BNUNBV1U2bzA4UT09',
#   'class_email': 'IA-class+RY296@northeastern.edu',
#   'class_password': '%w$[4C(dHDag',
#   'classroom': 'RY296',
#   'StartTime': '08:00:00',
#   'Day': 'W',
#   'CourseId': 'CHEM2321',
#   'assign_to': 1},
#  {'link': 'https://northeastern.zoom.us/j/96879452707?pwd=SWx6KzNoQ0MrM1lNSHdDM01sc1Mzdz09',
#   'class_email': 'IA-class+RY296@northeastern.edu',
#   'class_password': '%w$[4C(dHDag',
#   'classroom': 'RY296',
#   'StartTime': '09:15:00',
#   'Day': 'W',
#   'CourseId': 'MGSC2301',
#   'assign_to': 1}]

# %%
list(filter(lambda person: person['StartTime'] == '08:00:00', kick_list))
# Out:
# [{'link': 'https://northeastern.zoom.us/j/96879452707?pwd=SWx6KzNoQ0MrM1lNSHdDM01sc1Mzdz09',
#   'class_email': 'IA-class+RY157@northeastern.edu',
#   'class_password': 'qG5)9cS6/AsD',
#   'classroom': 'RY157',
#   'StartTime': '08:00:00',
#   'Day': 'W',
#   'CourseId': 'MGSC2301',
#   'assign_to': 1},
#  {'link': 'https://northeastern.zoom.us/j/95250289821?pwd=cG15Tmx0ZUlucG1BNUNBV1U2bzA4UT09',
#   'class_email': 'IA-class+RY296@northeastern.edu',
#   'class_password': '%w$[4C(dHDag',
#   'classroom': 'RY296',
#   'StartTime': '08:00:00',
#   'Day': 'W',
#   'CourseId': 'CHEM2321',
#   'assign_to': 1},
#  {'link': 'https://northeastern.zoom.us/j/97791356361',
#   'class_email': 'IA-class+RY273@northeastern.edu',
#   'class_password': 'NaN',
#   'classroom': 'RY273',
#   'StartTime': '08:00:00',
#   'Day': 'W',
#   'CourseId': 'BUSN1101',
#   'assign_to': 1},
#  {'link': 'Not Found',
#   'class_email': 'IA-class+RY275@northeastern.edu',
#   'class_password': '5UbY6&kZc%/$',
# ...
